# %%
from torch.utils.data import Dataset, DataLoader
from glob import glob
import numpy as np
import pandas as pd
import cv2
import torch
from PIL import Image
from torchvision.transforms import transforms
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
# !pwd
# Out:
# /Users/ap/Desktop/Code/pytorch_projects/dog_cat_classification/dogs-vs-cats

# %% [markdown]
# <h3> Create <code>torchvision</code> dataset for images </h3>
# <h4>
# <a href="https://pytorch.org/vision/stable/generated/torchvision.datasets.ImageFolder.html#torchvision.datasets.ImageFolder"> Link to the Pytorch `ImageFolder` class to create pytorch vision dataset having following directory structure.</a>
# </h4>
#
# ```json
# root/dog/xxx.png
# root/dog/xxy.png
# root/dog/[...]/xxz.png
#
# root/cat/123.png
# root/cat/nsdf3.png
# root/cat/[...]/asd932_.png
#
# ```

# %%
data_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor()])

train_dir = 'train'
train_data = datasets.ImageFolder(root=train_dir,
                                  transform=data_transform)


print(f"Train data:\n{train_data}\n")
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 25000
#     Root location: train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=None)
#                ToTensor()
#            )

# %%
train_data.class_to_idx
# Out:
# {'cats': 0, 'dogs': 1}

# %%
train_data[0]
# Out:
# (tensor([[[0.7961, 0.8039, 0.8157,  ..., 0.9569, 0.9451, 0.9373],
#           [0.7961, 0.8039, 0.8157,  ..., 0.9569, 0.9490, 0.9412],
#           [0.7961, 0.8039, 0.8157,  ..., 0.9608, 0.9490, 0.9412],
#           ...,
#           [0.6039, 0.6039, 0.6078,  ..., 0.0078, 0.0078, 0.0078],
#           [0.6000, 0.6000, 0.6039,  ..., 0.0078, 0.0078, 0.0078],
#           [0.5922, 0.5922, 0.5961,  ..., 0.0039, 0.0039, 0.0039]],
#
#          [[0.6431, 0.6510, 0.6627,  ..., 0.7961, 0.7882, 0.7843],
#           [0.6431, 0.6510, 0.6627,  ..., 0.8000, 0.7961, 0.7882],
#           [0.6431, 0.6510, 0.6627,  ..., 0.8000, 0.7961, 0.7882],
#           ...,
#           [0.4824, 0.4824, 0.4863,  ..., 0.0078, 0.0078, 0.0078],
#           [0.4784, 0.4784, 0.4824,  ..., 0.0078, 0.0078, 0.0078],
#           [0.4706, 0.4706, 0.4745,  ..., 0.0039, 0.0039, 0.0039]],
#
#          [[0.3412, 0.3490, 0.3608,  ..., 0.4706, 0.4784, 0.4745],
#           [0.3412, 0.3490, 0.3608,  ..., 0.4745, 0.4824, 0.4784],
#           [0.3412, 0.3490, 0.3608,  ..., 0.4784, 0.4824, 0.4784],
#           ...,
#           [0.2196, 0.2196, 0.2235,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2157, 0.2157, 0.2196,  ..., 0.0000, 0.0000, 0.0000],
#           [0.2078, 0.2078, 0.2118,  ..., 0.0000, 0.0000, 0.0000]]]),
#  0)

# %% [markdown]
# ### creating custom dataset using Dataset class

# %%
class catdogDataset(Dataset):
    
    def __init__(self, path: str, transform: bool = True):
                 
        self.imgs_path = path
        file_list = glob(self.imgs_path + "*")
        print(file_list)
        self.data = []
        for path in file_list:
            class_name = path.split('/')[-1]
            for img_path in glob(path + '/*'):
                self.data.append([img_path, class_name])
        print(self.data)
                
        self.class_map = {'dogs': 0, 'cats':1}
        self.img_dim = (256,256)
        
    def __len__(self):
        return len(self.data)
    

    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        img = Image.open(img_path)
        
        if self.transform:
            self.data_transform = transforms.Compose([
            transforms.Resize(size=self.img_dim),
            transforms.ToTensor()])
            self.data_transform(img)
        class_id = self.class_map[class_name]
        class_id = torch.tensor([class_id])
        return img_tensor, class_id
        # return img_path, class_name

# %%
custom_dataset = catdogDataset('./train/')
# Out:
# ['./train/dogs', './train/cats']
# [['./train/dogs/dog.8011.jpg', 'dogs'], ['./train/dogs/dog.7322.jpg', 'dogs'], ['./train/dogs/dog.1753.jpg', 'dogs'], ['./train/dogs/dog.5535.jpg', 'dogs'], ['./train/dogs/dog.3144.jpg', 'dogs'], ['./train/dogs/dog.775.jpg', 'dogs'], ['./train/dogs/dog.11102.jpg', 'dogs'], ['./train/dogs/dog.11664.jpg', 'dogs'], ['./train/dogs/dog.3622.jpg', 'dogs'], ['./train/dogs/dog.5253.jpg', 'dogs'], ['./train/dogs/dog.9469.jpg', 'dogs'], ['./train/dogs/dog.1035.jpg', 'dogs'], ['./train/dogs/dog.6982.jpg', 'dogs'], ['./train/dogs/dog.8777.jpg', 'dogs'], ['./train/dogs/dog.7444.jpg', 'dogs'], ['./train/dogs/dog.1021.jpg', 'dogs'], ['./train/dogs/dog.6996.jpg', 'dogs'], ['./train/dogs/dog.8763.jpg', 'dogs'], ['./train/dogs/dog.7450.jpg', 'dogs'], ['./train/dogs/dog.12379.jpg', 'dogs'], ['./train/dogs/dog.11670.jpg', 'dogs'], ['./train/dogs/dog.4159.jpg', 'dogs'], ['./train/dogs/dog.3636.jpg', 'dogs'], ['./train/dogs/dog.2528.jpg', 'dogs'], ['./train/dogs/dog.5247.jpg', 'dogs'], ['./train/dogs/dog.10208.jpg', 'dogs'], ['./train/dogs/dog.5521.jpg', 'dogs'], ['./train/dogs/dog.761.jpg', 'dogs'], ['./train/dogs/dog.3150.jpg', 'dogs'], ['./train/dogs/dog.11116.jpg', 'dogs'], ['./train/dogs/dog.8005.jpg', 'dogs'], ['./train/dogs/dog.7336.jpg', 'dogs'], ['./train/dogs/dog.1747.jpg', 'dogs'], ['./train/dogs/dog.6028.jpg', 'dogs'], ['./train/dogs/dog.991.jpg', 'dogs'], ['./train/dogs/dog.5509.jpg', 'dogs'], ['./train/dogs/dog.10220.jpg', 'dogs'], ['./train/dogs/dog.2266.jpg', 'dogs'], ['./train/dogs/dog.3178.jpg', 'dogs'], ['./train/dogs/dog.749.jpg', 'dogs'], ['./train/dogs/dog.4617.jpg', 'dogs'], ['./train/dogs/dog.12437.jpg', 'dogs'], ['./train/dogs/dog.6000.jpg', 'dogs'], ['./train/dogs/dog.9333.jpg', 'dogs'], ['./train/dogs/dog.6766.jpg', 'dogs'], ['./train/dogs/dog.9455.jpg', 'dogs'], ['./train/dogs/dog.8993.jpg', 'dogs'], ['./train/dogs/dog.1009.jpg', 'dogs'], ['./train/dogs/dog.12351.jpg', 'dogs'], ['./train/dogs/dog.7478.jpg', 'dogs'], ['./train/dogs/dog.4171.jpg', 'dogs'], ['./train/dogs/dog.11658.jpg', 'dogs'], ['./train/dogs/dog.2500.jpg', 'dogs'], ['./train/dogs/dog.11880.jpg', 'dogs'], ['./train/dogs/dog.10546.jpg', 'dogs'], ['./train/dogs/dog.4165.jpg', 'dogs'], ['./train/dogs/dog.2514.jpg', 'dogs'], ['./train/dogs/dog.11894.jpg', 'dogs'], ['./train/dogs/dog.10552.jpg', 'dogs'], ['./train/dogs/dog.6772.jpg', 'dogs'], ['./train/dogs/dog.9441.jpg', 'dogs'], ['./train/dogs/dog.8987.jpg', 'dogs'], ['./train/dogs/dog.12345.jpg', 'dogs'], ['./train/dogs/dog.12423.jpg', 'dogs'], ['./train/dogs/dog.8039.jpg', 'dogs'], ['./train/dogs/dog.6014.jpg', 'dogs'], ['./train/dogs/dog.9327.jpg', 'dogs'], ['./train/dogs/dog.985.jpg', 'dogs'], ['./train/dogs/dog.10234.jpg', 'dogs'], ['./train/dogs/dog.2272.jpg', 'dogs'], ['./train/dogs/dog.4603.jpg', 'dogs'], ['./train/dogs/dog.3187.jpg', 'dogs'], ['./train/dogs/dog.4830.jpg', 'dogs'], ['./train/dogs/dog.2299.jpg', 'dogs'], ['./train/dogs/dog.1790.jpg', 'dogs'], ['./train/dogs/dog.1948.jpg', 'dogs'], ['./train/dogs/dog.6941.jpg', 'dogs'], ['./train/dogs/dog.7487.jpg', 'dogs'], ['./train/dogs/dog.6799.jpg', 'dogs'], ['./train/dogs/dog.5290.jpg', 'dogs'], ['./train/dogs/dog.3839.jpg', 'dogs'], ['./train/dogs/dog.5284.jpg', 'dogs'], ['./train/dogs/dog.6955.jpg', 'dogs'], ['./train/dogs/dog.7493.jpg', 'dogs'], ['./train/dogs/dog.8978.jpg', 'dogs'], ['./train/dogs/dog.1784.jpg', 'dogs'], ['./train/dogs/dog.3193.jpg', 'dogs'], ['./train/dogs/dog.4824.jpg', 'dogs'], ['./train/dogs/dog.1974.jpg', 'dogs'], ['./train/dogs/dog.952.jpg', 'dogs'], ['./train/dogs/dog.11843.jpg', 'dogs'], ['./train/dogs/dog.3805.jpg', 'dogs'], ['./train/dogs/dog.10585.jpg', 'dogs'], ['./train/dogs/dog.12392.jpg', 'dogs'], ['./train/dogs/dog.8788.jpg', 'dogs'], ['./train/dogs/dog.9496.jpg', 'dogs'], ['./train/dogs/dog.8950.jpg', 'dogs'], ['./train/dogs/dog.6969.jpg', 'dogs'], ['./train/dogs/dog.12386.jpg', 'dogs'], ['./train/dogs/dog.9482.jpg', 'dogs'], ['./train/dogs/dog.8944.jpg', 'dogs'], ['./train/dogs/dog.11857.jpg', 'dogs'], ['./t ...

# %%
custom_dataset[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 custom_dataset[0]
#
# Input In [6], in catdogDataset.__getitem__(self, idx)
#      23 img_path, class_name = self.data[idx]
#      24 img = Image.open(img_path)
# ---> 26 if self.transform:
#      27     self.data_transform = transforms.Compose([
#      28     transforms.Resize(size=self.img_dim),
#      29     transforms.ToTensor()])
#      30     self.data_transform(img)
#
# AttributeError: 'catdogDataset' object has no attribute 'transform'

# %%
root_dir = './train/'
sub_dirs = glob(root_dir + '*')
data = []
for path in sub_dirs:
    class_ = path.split('/')[-1]
    for files in glob(path + '/*'):
        data.append([files, class_])

# %%
data
# Out:
# [['./train/dogs/dog.8011.jpg', 'dogs'],
#  ['./train/dogs/dog.7322.jpg', 'dogs'],
#  ['./train/dogs/dog.1753.jpg', 'dogs'],
#  ['./train/dogs/dog.5535.jpg', 'dogs'],
#  ['./train/dogs/dog.3144.jpg', 'dogs'],
#  ['./train/dogs/dog.775.jpg', 'dogs'],
#  ['./train/dogs/dog.11102.jpg', 'dogs'],
#  ['./train/dogs/dog.11664.jpg', 'dogs'],
#  ['./train/dogs/dog.3622.jpg', 'dogs'],
#  ['./train/dogs/dog.5253.jpg', 'dogs'],
#  ['./train/dogs/dog.9469.jpg', 'dogs'],
#  ['./train/dogs/dog.1035.jpg', 'dogs'],
#  ['./train/dogs/dog.6982.jpg', 'dogs'],
#  ['./train/dogs/dog.8777.jpg', 'dogs'],
#  ['./train/dogs/dog.7444.jpg', 'dogs'],
#  ['./train/dogs/dog.1021.jpg', 'dogs'],
#  ['./train/dogs/dog.6996.jpg', 'dogs'],
#  ['./train/dogs/dog.8763.jpg', 'dogs'],
#  ['./train/dogs/dog.7450.jpg', 'dogs'],
#  ['./train/dogs/dog.12379.jpg', 'dogs'],
#  ['./train/dogs/dog.11670.jpg', 'dogs'],
#  ['./train/dogs/dog.4159.jpg', 'dogs'],
#  ['./train/dogs/dog.3636.jpg', 'dogs'],
#  ['./train/dogs/dog.2528.jpg', 'dogs'],
#  ['./train/dogs/dog.5247.jpg', 'dogs'],
#  ['./train/dogs/dog.10208.jpg', 'dogs'],
#  ['./train/dogs/dog.5521.jpg', 'dogs'],
#  ['./train/dogs/dog.761.jpg', 'dogs'],
#  ['./train/dogs/dog.3150.jpg', 'dogs'],
#  ['./train/dogs/dog.11116.jpg', 'dogs'],
#  ['./train/dogs/dog.8005.jpg', 'dogs'],
#  ['./train/dogs/dog.7336.jpg', 'dogs'],
#  ['./train/dogs/dog.1747.jpg', 'dogs'],
#  ['./train/dogs/dog.6028.jpg', 'dogs'],
#  ['./train/dogs/dog.991.jpg', 'dogs'],
#  ['./train/dogs/dog.5509.jpg', 'dogs'],
#  ['./train/dogs/dog.10220.jpg', 'dogs'],
#  ['./train/dogs/dog.2266.jpg', 'dogs'],
#  ['./train/dogs/dog.3178.jpg', 'dogs'],
#  ['./train/dogs/dog.749.jpg', 'dogs'],
#  ['./train/dogs/dog.4617.jpg', 'dogs'],
#  ['./train/dogs/dog.12437.jpg', 'dogs'],
#  ['./train/dogs/dog.6000.jpg', 'dogs'],
#  ['./train/dogs/dog.9333.jpg', 'dogs'],
#  ['./train/dogs/dog.6766.jpg', 'dogs'],
#  ['./train/dogs/dog.9455.jpg', 'dogs'],
#  ['./train/dogs/dog.8993.jpg', 'dogs'],
#  ['./train/dogs/dog.1009.jpg', 'dogs'],
#  ['./train/dogs/dog.12351.jpg', 'dogs'],
#  ['./train/dogs/dog.7478.jpg', 'dogs'],
#  ['./train/dogs/dog.4171.jpg', 'dogs'],
#  ['./train/dogs/dog.11658.jpg', 'dogs'],
#  ['./train/dogs/dog.2500.jpg', 'dogs'],
#  ['./train/dogs/dog.11880.jpg', 'dogs'],
#  ['./train/dogs/dog.10546.jpg', 'dogs'],
#  ['./train/dogs/dog.4165.jpg', 'dogs'],
#  ['./train/dogs/dog.2514.jpg', 'dogs'],
#  ['./train/dogs/dog.11894.jpg', 'dogs'],
#  ['./train/dogs/dog.10552.jpg', 'dogs'],
#  ['./train/dogs/dog.6772.jpg', 'dogs'],
#  ['./train/dogs/dog.9441.jpg', 'dogs'],
#  ['./train/dogs/dog.8987.jpg', 'dogs'],
#  ['./train/dogs/dog.12345.jpg', 'dogs'],
#  ['./train/dogs/dog.12423.jpg', 'dogs'],
#  ['./train/dogs/dog.8039.jpg', 'dogs'],
#  ['./train/dogs/dog.6014.jpg', 'dogs'],
#  ['./train/dogs/dog.9327.jpg', 'dogs'],
#  ['./train/dogs/dog.985.jpg', 'dogs'],
#  ['./train/dogs/dog.10234.jpg', 'dogs'],
#  ['./train/dogs/dog.2272.jpg', 'dogs'],
#  ['./train/dogs/dog.4603.jpg', 'dogs'],
#  ['./train/dogs/dog.3187.jpg', 'dogs'],
#  ['./train/dogs/dog.4830.jpg', 'dogs'],
#  ['./train/dogs/dog.2299.jpg', 'dogs'],
#  ['./train/dogs/dog.1790.jpg', 'dogs'],
#  ['./train/dogs/dog.1948.jpg', 'dogs'],
#  ['./train/dogs/dog.6941.jpg', 'dogs'],
#  ['./train/dogs/dog.7487.jpg', 'dogs'],
#  ['./train/dogs/dog.6799.jpg', 'dogs'],
#  ['./train/dogs/dog.5290.jpg', 'dogs'],
#  ['./train/dogs/dog.3839.jpg', 'dogs'],
#  ['./train/dogs/dog.5284.jpg', 'dogs'],
#  ['./train/dogs/dog.6955.jpg', 'dogs'],
#  ['./train/dogs/dog.7493.jpg', 'dogs'],
#  ['./train/dogs/dog.8978.jpg', 'dogs'],
#  ['./train/dogs/dog.1784.jpg', 'dogs'],
#  ['./train/dogs/dog.3193.jpg', 'dogs'],
#  ['./train/dogs/dog.4824.jpg', 'dogs'],
#  ['./train/dogs/dog.1974.jpg', 'dogs'],
#  ['./train/dogs/dog.952.jpg', 'dogs'],
#  ['./train/dogs/dog.11843.jpg', 'dogs'],
#  ['./train/dogs/dog.3805.jpg', 'dogs'],
#  ['./train/dogs/dog.10585.jpg', 'dogs'],
#  ['./train/dogs/dog.12392.jpg', 'dogs'],
#  ['./train/dogs/dog.8788.jpg', 'dogs'],
#  ['./train/dogs/dog.9496.jpg', 'dogs'],
#  ['./train/dogs/dog.8950.jpg', 'dogs'],
#  ['./train/dogs/dog.6969.jpg', 'dogs'],
#  ['./train/dogs/dog.12386.jpg', 'dogs'],
#  ['./train/dogs/dog.9482.jpg', 'dogs'],
#  ['./train/dogs/dog.8944.jpg', 'dogs'],
#  ['./train/dogs/dog.11857.jpg', 'dogs'],
#  ['./train/dogs/dog.3811.jpg', 'dogs'],
#  ['./train/dogs/dog.10591.jpg', 'dogs'],
#  ['./train/dogs/dog.946.jpg', 'dogs'],
#  ['./train/dogs/dog.4818.jpg', 'dogs'],
#  ['./train/dogs/dog.1960.jpg', 'dogs'],
#  ['./train/dogs/dog.7646.jpg', 'dogs'],
#  ['./train/dogs/dog.8575.jpg', 'dogs'],
#  ['./train/dogs/dog.1237.jpg', 'dogs'],
#  ['./train/dogs/dog.6558.jpg', 'dogs'],
#  ['./train/dogs/dog.5051.jpg', 'dogs'],
#  ['./train/dogs/dog.10778.jpg', 'dogs'],
#  ['./train/dogs/dog.3420.jpg', 'dogs'],
#  ['./train/dogs/dog.211.jpg', 'dogs'],
#  ['./train/dogs/dog.11466.jpg', 'dogs'],
#  ['./train/dogs/dog.4429.jpg', 'dogs'],
#  ['./train/dogs/dog.11300.jpg', 'dogs'],
#  ['./train/dogs/dog.3346.jpg', 'dogs'],
#  ['./train/dogs/dog.577.jpg', 'dogs'],
#  ['./train/dogs/dog.2058.jpg', 'dogs'],
#  ['./train/dogs/dog.5737.jpg', 'dogs'],
#  ['./train/dogs/dog.1551.jpg', 'dogs'],
#  ['./train/dogs/dog.7120.jpg', 'dogs'],
#  ['./train/dogs/dog.8213.jpg', 'dogs'],
#  ['./train/dogs/dog.9119.jpg', 'dogs'],
#  ['./train/dogs/dog.1545.jpg', 'dogs'],
#  ['./train/dogs/dog.7134.jpg', 'dogs'],
#  ['./train/dogs/dog.8207.jpg', 'dogs'],
#  ['./train/dogs/dog.11314.jpg', 'dogs'],
#  ['./train/dogs/dog.563.jpg', 'dogs'],
#  ['./train/dogs/dog.3352.jpg', 'dogs'],
#  ['./train/dogs/dog.5723.jpg', 'dogs'],
#  ['./train/dogs/dog.5045.jpg', 'dogs'],
#  ['./train/dogs/dog.205.jpg', 'dogs'],
#  ['./train/dogs/dog.3434.jpg', 'dogs'],
#  ['./train/dogs/dog.11472.jpg', 'dogs'],
#  ['./train/dogs/dog.7652.jpg', 'dogs'],
#  ['./train/dogs/dog.8561.jpg', 'dogs'],
#  ['./train/dogs/dog.1223.jpg', 'dogs'],
#  ['./train/dogs/dog.10744.jpg', 'dogs'],
#  ['./train/dogs/dog.2702.jpg', 'dogs'],
#  ['./train/dogs/dog.4373.jpg', 'dogs'],
#  ['./train/dogs/dog.8549.jpg', 'dogs'],
#  ['./train/dogs/dog.12153.jpg', 'dogs'],
#  ['./train/dogs/dog.9657.jpg', 'dogs'],
#  ['./train/dogs/dog.6564.jpg', 'dogs'],
#  ['./train/dogs/dog.9131.jpg', 'dogs'],
#  ['./train/dogs/dog.6202.jpg', 'dogs'],
#  ['./train/dogs/dog.4415.jpg', 'dogs'],
#  ['./train/dogs/dog.2064.jpg', 'dogs'],
#  ['./train/dogs/dog.10022.jpg', 'dogs'],
#  ['./train/dogs/dog.11328.jpg', 'dogs'],
#  ['./train/dogs/dog.4401.jpg', 'dogs'],
#  ['./train/dogs/dog.2070.jpg', 'dogs'],
#  ['./train/dogs/dog.10036.jpg', 'dogs'],
#  ['./train/dogs/dog.9125.jpg', 'dogs'],
#  ['./train/dogs/dog.6216.jpg', 'dogs'],
#  ['./train/dogs/dog.1579.jpg', 'dogs'],
#  ['./train/dogs/dog.7108.jpg', 'dogs'],
#  ['./train/dogs/dog.12147.jpg', 'dogs'],
#  ['./train/dogs/dog.9643.jpg', 'dogs'],
#  ['./train/dogs/dog.6570.jpg', 'dogs'],
#  ['./train/dogs/dog.10750.jpg', 'dogs'],
#  ['./train/dogs/dog.5079.jpg', 'dogs'],
#  ['./train/dogs/dog.2716.jpg', 'dogs'],
#  ['./train/dogs/dog.10988.jpg', 'dogs'],
#  ['./train/dogs/dog.239.jpg', 'dogs'],
#  ['./train/dogs/dog.3408.jpg', 'dogs'],
#  ['./train/dogs/dog.4367.jpg', 'dogs'],
#  ['./train/dogs/dog.10963.jpg', 'dogs'],
#  ['./train/dogs/dog.2925.jpg', 'dogs'],
#  ['./train/dogs/dog.5092.jpg', 'dogs'],
#  ['./train/dogs/dog.7685.jpg', 'dogs'],
#  ['./train/dogs/dog.9870.jpg', 'dogs'],
#  ['./train/dogs/dog.1592.jpg', 'dogs'],
#  ['./train/dogs/dog.3385.jpg', 'dogs'],
#  ['./train/dogs/dog.3391.jpg', 'dogs'],
#  ['./train/dogs/dog.5938.jpg', 'dogs'],
#  ['./train/dogs/dog.1586.jpg', 'dogs'],
#  ['./train/dogs/dog.7849.jpg', 'dogs'],
#  ['./train/dogs/dog.7691.jpg', 'dogs'],
#  ['./train/dogs/dog.9864.jpg', 'dogs'],
#  ['./train/dogs/dog.10977.jpg', 'dogs'],
#  ['./train/dogs/dog.2931.jpg', 'dogs'],
#  ['./train/dogs/dog.4398.jpg', 'dogs'],
#  ['./train/dogs/dog.5086.jpg', 'dogs'],
#  ['./train/dogs/dog.7861.jpg', 'dogs'],
#  ['./train/dogs/dog.9694.jpg', 'dogs'],
#  ['./train/dogs/dog.12190.jpg', 'dogs'],
#  ['./train/dogs/dog.11499.jpg', 'dogs'],
#  ['./train/dogs/dog.2919.jpg', 'dogs'],
#  ['./train/dogs/dog.10787.jpg', 'dogs'],
#  ['./train/dogs/dog.5910.jpg', 'dogs'],
#  ['./train/dogs/dog.588.jpg', 'dogs'],
#  ['./train/dogs/dog.5904.jpg', 'dogs'],
#  ['./train/dogs/dog.10793.jpg', 'dogs'],
#  ['./train/dogs/dog.7875.jpg', 'dogs'],
#  ['./train/dogs/dog.9680.jpg', 'dogs'],
#  ['./train/dogs/dog.12184.jpg', 'dogs'],
#  ['./train/dogs/dog.9858.jpg', 'dogs'],
#  ['./train/dogs/dog.1343.jpg', 'dogs'],
#  ['./train/dogs/dog.7732.jpg', 'dogs'],
#  ['./train/dogs/dog.8401.jpg', 'dogs'],
#  ['./train/dogs/dog.2892.jpg', 'dogs'],
#  ['./train/dogs/dog.11512.jpg', 'dogs'],
#  ['./train/dogs/dog.365.jpg', 'dogs'],
#  ['./train/dogs/dog.3554.jpg', 'dogs'],
#  ['./train/dogs/dog.5125.jpg', 'dogs'],
#  ['./train/dogs/dog.5643.jpg', 'dogs'],
#  ['./train/dogs/dog.403.jpg', 'dogs'],
#  ['./train/dogs/dog.3232.jpg', 'dogs'],
#  ['./train/dogs/dog.11274.jpg', 'dogs'],
#  ['./train/dogs/dog.7054.jpg', 'dogs'],
#  ['./train/dogs/dog.8367.jpg', 'dogs'],
#  ['./train/dogs/dog.1425.jpg', 'dogs'],
#  ['./train/dogs/dog.9079.jpg', 'dogs'],
#  ['./train/dogs/dog.7040.jpg', 'dogs'],
#  ['./train/dogs/dog.8373.jpg', 'dogs'],
#  ['./train/dogs/dog.1431.jpg', 'dogs'],
#  ['./train/dogs/dog.5657.jpg', 'dogs'],
#  ['./train/dogs/dog.2138.jpg', 'dogs'],
#  ['./train/dogs/dog.3226.jpg', 'dogs'],
#  ['./train/dogs/dog.417.jpg', 'dogs'],
#  ['./train/dogs/dog.4549.jpg', 'dogs'],
#  ['./train/dogs/dog.11260.jpg', 'dogs'],
#  ['./train/dogs/dog.2886.jpg', 'dogs'],
#  ['./train/dogs/dog.11506.jpg', 'dogs'],
#  ['./train/dogs/dog.3540.jpg', 'dogs'],
#  ['./train/dogs/dog.371.jpg', 'dogs'],
#  ['./train/dogs/dog.5131.jpg', 'dogs'],
#  ['./train/dogs/dog.10618.jpg', 'dogs'],
#  ['./train/dogs/dog.6438.jpg', 'dogs'],
#  ['./train/dogs/dog.1357.jpg', 'dogs'],
#  ['./train/dogs/dog.7726.jpg', 'dogs'],
#  ['./train/dogs/dog.8415.jpg', 'dogs'],
#  ['./train/dogs/dog.4207.jpg', 'dogs'],
#  ['./train/dogs/dog.359.jpg', 'dogs'],
#  ['./train/dogs/dog.3568.jpg', 'dogs'],
#  ['./train/dogs/dog.2676.jpg', 'dogs'],
#  ['./train/dogs/dog.10630.jpg', 'dogs'],
#  ['./train/dogs/dog.5119.jpg', 'dogs'],
#  ['./train/dogs/dog.9723.jpg', 'dogs'],
#  ['./train/dogs/dog.6410.jpg', 'dogs'],
#  ['./train/dogs/dog.12027.jpg', 'dogs'],
#  ['./train/dogs/dog.7068.jpg', 'dogs'],
#  ['./train/dogs/dog.1419.jpg', 'dogs'],
#  ['./train/dogs/dog.9045.jpg', 'dogs'],
#  ['./train/dogs/dog.6376.jpg', 'dogs'],
#  ['./train/dogs/dog.10156.jpg', 'dogs'],
#  ['./train/dogs/dog.2110.jpg', 'dogs'],
#  ['./train/dogs/dog.11248.jpg', 'dogs'],
#  ['./train/dogs/dog.4561.jpg', 'dogs'],
#  ['./train/dogs/dog.10142.jpg', 'dogs'],
#  ['./train/dogs/dog.2104.jpg', 'dogs'],
#  ['./train/dogs/dog.4575.jpg', 'dogs'],
#  ['./train/dogs/dog.9051.jpg', 'dogs'],
#  ['./train/dogs/dog.6362.jpg', 'dogs'],
#  ['./train/dogs/dog.9737.jpg', 'dogs'],
#  ['./train/dogs/dog.6404.jpg', 'dogs'],
#  ['./train/dogs/dog.8429.jpg', 'dogs'],
#  ['./train/dogs/dog.12033.jpg', 'dogs'],
#  ['./train/dogs/dog.4213.jpg', 'dogs'],
#  ['./train/dogs/dog.2662.jpg', 'dogs'],
#  ['./train/dogs/dog.10624.jpg', 'dogs'],
#  ['./train/dogs/dog.2689.jpg', 'dogs'],
#  ['./train/dogs/dog.2851.jpg', 'dogs'],
#  ['./train/dogs/dog.3597.jpg', 'dogs'],
#  ['./train/dogs/dog.10817.jpg', 'dogs'],
#  ['./train/dogs/dog.9904.jpg', 'dogs'],
#  ['./train/dogs/dog.7929.jpg', 'dogs'],
#  ['./train/dogs/dog.1380.jpg', 'dogs'],
#  ['./train/dogs/dog.6389.jpg', 'dogs'],
#  ['./train/dogs/dog.7097.jpg', 'dogs'],
#  ['./train/dogs/dog.5858.jpg', 'dogs'],
#  ['./train/dogs/dog.5680.jpg', 'dogs'],
#  ['./train/dogs/dog.5694.jpg', 'dogs'],
#  ['./train/dogs/dog.7083.jpg', 'dogs'],
#  ['./train/dogs/dog.9910.jpg', 'dogs'],
#  ['./train/dogs/dog.1394.jpg', 'dogs'],
#  ['./train/dogs/dog.2845.jpg', 'dogs'],
#  ['./train/dogs/dog.3583.jpg', 'dogs'],
#  ['./train/dogs/dog.10803.jpg', 'dogs'],
#  ['./train/dogs/dog.9938.jpg', 'dogs'],
#  ['./train/dogs/dog.7915.jpg', 'dogs'],
#  ['./train/dogs/dog.5864.jpg', 'dogs'],
#  ['./train/dogs/dog.10195.jpg', 'dogs'],
#  ['./train/dogs/dog.9086.jpg', 'dogs'],
#  ['./train/dogs/dog.8398.jpg', 'dogs'],
#  ['./train/dogs/dog.9092.jpg', 'dogs'],
#  ['./train/dogs/dog.5870.jpg', 'dogs'],
#  ['./train/dogs/dog.10181.jpg', 'dogs'],
#  ['./train/dogs/dog.2879.jpg', 'dogs'],
#  ['./train/dogs/dog.7901.jpg', 'dogs'],
#  ['./train/dogs/dog.6148.jpg', 'dogs'],
#  ['./train/dogs/dog.1627.jpg', 'dogs'],
#  ['./train/dogs/dog.8165.jpg', 'dogs'],
#  ['./train/dogs/dog.7256.jpg', 'dogs'],
#  ['./train/dogs/dog.11076.jpg', 'dogs'],
#  ['./train/dogs/dog.601.jpg', 'dogs'],
#  ['./train/dogs/dog.3030.jpg', 'dogs'],
#  ['./train/dogs/dog.4987.jpg', 'dogs'],
#  ['./train/dogs/dog.10368.jpg', 'dogs'],
#  ['./train/dogs/dog.5441.jpg', 'dogs'],
#  ['./train/dogs/dog.5327.jpg', 'dogs'],
#  ['./train/dogs/dog.2448.jpg', 'dogs'],
#  ['./train/dogs/dog.167.jpg', 'dogs'],
#  ['./train/dogs/dog.3756.jpg', 'dogs'],
#  ['./train/dogs/dog.11710.jpg', 'dogs'],
#  ['./train/dogs/dog.4039.jpg', 'dogs'],
#  ['./train/dogs/dog.8603.jpg', 'dogs'],
#  ['./train/dogs/dog.7530.jpg', 'dogs'],
#  ['./train/dogs/dog.12219.jpg', 'dogs'],
#  ['./train/dogs/dog.1141.jpg', 'dogs'],
#  ['./train/dogs/dog.8617.jpg', 'dogs'],
#  ['./train/dogs/dog.7524.jpg', 'dogs'],
#  ['./train/dogs/dog.1155.jpg', 'dogs'],
#  ['./train/dogs/dog.9509.jpg', 'dogs'],
#  ['./train/dogs/dog.5333.jpg', 'dogs'],
#  ['./train/dogs/dog.3742.jpg', 'dogs'],
#  ['./train/dogs/dog.173.jpg', 'dogs'],
#  ['./train/dogs/dog.11704.jpg', 'dogs'],
#  ['./train/dogs/dog.11062.jpg', 'dogs'],
#  ['./train/dogs/dog.3024.jpg', 'dogs'],
#  ['./train/dogs/dog.615.jpg', 'dogs'],
#  ['./train/dogs/dog.4993.jpg', 'dogs'],
#  ['./train/dogs/dog.5455.jpg', 'dogs'],
#  ['./train/dogs/dog.1633.jpg', 'dogs'],
#  ['./train/dogs/dog.8171.jpg', 'dogs'],
#  ['./train/dogs/dog.7242.jpg', 'dogs'],
#  ['./train/dogs/dog.4763.jpg', 'dogs'],
#  ['./train/dogs/dog.2312.jpg', 'dogs'],
#  ['./train/dogs/dog.10354.jpg', 'dogs'],
#  ['./train/dogs/dog.6174.jpg', 'dogs'],
#  ['./train/dogs/dog.9247.jpg', 'dogs'],
#  ['./train/dogs/dog.36.jpg', 'dogs'],
#  ['./train/dogs/dog.8159.jpg', 'dogs'],
#  ['./train/dogs/dog.12225.jpg', 'dogs'],
#  ['./train/dogs/dog.6612.jpg', 'dogs'],
#  ['./train/dogs/dog.9521.jpg', 'dogs'],
#  ['./train/dogs/dog.10432.jpg', 'dogs'],
#  ['./train/dogs/dog.2474.jpg', 'dogs'],
#  ['./train/dogs/dog.4005.jpg', 'dogs'],
#  ['./train/dogs/dog.10426.jpg', 'dogs'],
#  ['./train/dogs/dog.2460.jpg', 'dogs'],
#  ['./train/dogs/dog.4011.jpg', 'dogs'],
#  ['./train/dogs/dog.11738.jpg', 'dogs'],
#  ['./train/dogs/dog.12231.jpg', 'dogs'],
#  ['./train/dogs/dog.7518.jpg', 'dogs'],
#  ['./train/dogs/dog.1169.jpg', 'dogs'],
#  ['./train/dogs/dog.6606.jpg', 'dogs'],
#  ['./train/dogs/dog.9535.jpg', 'dogs'],
#  ['./train/dogs/dog.6160.jpg', 'dogs'],
#  ['./train/dogs/dog.9253.jpg', 'dogs'],
#  ['./train/dogs/dog.22.jpg', 'dogs'],
#  ['./train/dogs/dog.4777.jpg', 'dogs'],
#  ['./train/dogs/dog.3018.jpg', 'dogs'],
#  ['./train/dogs/dog.629.jpg', 'dogs'],
#  ['./train/dogs/dog.2306.jpg', 'dogs'],
#  ['./train/dogs/dog.5469.jpg', 'dogs'],
#  ['./train/dogs/dog.10340.jpg', 'dogs'],
#  ['./train/dogs/dog.4944.jpg', 'dogs'],
#  ['./train/dogs/dog.5482.jpg', 'dogs'],
#  ['./train/dogs/dog.7295.jpg', 'dogs'],
#  ['./train/dogs/dog.8818.jpg', 'dogs'],
#  ['./train/dogs/dog.1182.jpg', 'dogs'],
#  ['./train/dogs/dog.6835.jpg', 'dogs'],
#  ['./train/dogs/dog.3795.jpg', 'dogs'],
#  ['./train/dogs/dog.3781.jpg', 'dogs'],
#  ['./train/dogs/dog.3959.jpg', 'dogs'],
#  ['./train/dogs/dog.1196.jpg', 'dogs'],
#  ['./train/dogs/dog.6821.jpg', 'dogs'],
#  ['./train/dogs/dog.1828.jpg', 'dogs'],
#  ['./train/dogs/dog.7281.jpg', 'dogs'],
#  ['./train/dogs/dog.4950.jpg', 'dogs'],
#  ['./train/dogs/dog.5496.jpg', 'dogs'],
#  ['./train/dogs/dog.4788.jpg', 'dogs'],
#  ['./train/dogs/dog.1800.jpg', 'dogs'],
#  ['./train/dogs/dog.9284.jpg', 'dogs'],
#  ['./train/dogs/dog.4978.jpg', 'dogs'],
#  ['./train/dogs/dog.826.jpg', 'dogs'],
#  ['./train/dogs/dog.10397.jpg', 'dogs'],
#  ['./train/dogs/dog.11089.jpg', 'dogs'],
#  ['./train/dogs/dog.198.jpg', 'dogs'],
#  ['./train/dogs/dog.3971.jpg', 'dogs'],
#  ['./train/dogs/dog.11937.jpg', 'dogs'],
#  ['./train/dogs/dog.8824.jpg', 'dogs'],
#  ['./train/dogs/dog.6809.jpg', 'dogs'],
#  ['./train/dogs/dog.8830.jpg', 'dogs'],
#  ['./train/dogs/dog.3965.jpg', 'dogs'],
#  ['./train/dogs/dog.11923.jpg', 'dogs'],
#  ['./train/dogs/dog.832.jpg', 'dogs'],
#  ['./train/dogs/dog.10383.jpg', 'dogs'],
#  ['./train/dogs/dog.1814.jpg', 'dogs'],
#  ['./train/dogs/dog.9290.jpg', 'dogs'],
#  ['./train/dogs/dog.11922.jpg', 'dogs'],
#  ['./train/dogs/dog.3964.jpg', 'dogs'],
#  ['./train/dogs/dog.8831.jpg', 'dogs'],
#  ['./train/dogs/dog.9291.jpg', 'dogs'],
#  ['./train/dogs/dog.1815.jpg', 'dogs'],
#  ['./train/dogs/dog.10382.jpg', 'dogs'],
#  ['./train/dogs/dog.833.jpg', 'dogs'],
#  ['./train/dogs/dog.11088.jpg', 'dogs'],
#  ['./train/dogs/dog.10396.jpg', 'dogs'],
#  ['./train/dogs/dog.827.jpg', 'dogs'],
#  ['./train/dogs/dog.4979.jpg', 'dogs'],
#  ['./train/dogs/dog.9285.jpg', 'dogs'],
#  ['./train/dogs/dog.1801.jpg', 'dogs'],
#  ['./train/dogs/dog.6808.jpg', 'dogs'],
#  ['./train/dogs/dog.8825.jpg', 'dogs'],
#  ['./train/dogs/dog.11936.jpg', 'dogs'],
#  ['./train/dogs/dog.3970.jpg', 'dogs'],
#  ['./train/dogs/dog.199.jpg', 'dogs'],
#  ['./train/dogs/dog.6820.jpg', 'dogs'],
#  ['./train/dogs/dog.1197.jpg', 'dogs'],
#  ['./train/dogs/dog.3958.jpg', 'dogs'],
#  ['./train/dogs/dog.3780.jpg', 'dogs'],
#  ['./train/dogs/dog.4789.jpg', 'dogs'],
#  ['./train/dogs/dog.5497.jpg', 'dogs'],
#  ['./train/dogs/dog.4951.jpg', 'dogs'],
#  ['./train/dogs/dog.7280.jpg', 'dogs'],
#  ['./train/dogs/dog.1829.jpg', 'dogs'],
#  ['./train/dogs/dog.7294.jpg', 'dogs'],
#  ['./train/dogs/dog.5483.jpg', 'dogs'],
#  ['./train/dogs/dog.4945.jpg', 'dogs'],
#  ['./train/dogs/dog.3794.jpg', 'dogs'],
#  ['./train/dogs/dog.6834.jpg', 'dogs'],
#  ['./train/dogs/dog.8819.jpg', 'dogs'],
#  ['./train/dogs/dog.1183.jpg', 'dogs'],
#  ['./train/dogs/dog.9534.jpg', 'dogs'],
#  ['./train/dogs/dog.6607.jpg', 'dogs'],
#  ['./train/dogs/dog.1168.jpg', 'dogs'],
#  ['./train/dogs/dog.7519.jpg', 'dogs'],
#  ['./train/dogs/dog.12230.jpg', 'dogs'],
#  ['./train/dogs/dog.11739.jpg', 'dogs'],
#  ['./train/dogs/dog.4010.jpg', 'dogs'],
#  ['./train/dogs/dog.2461.jpg', 'dogs'],
#  ['./train/dogs/dog.10427.jpg', 'dogs'],
#  ['./train/dogs/dog.10341.jpg', 'dogs'],
#  ['./train/dogs/dog.5468.jpg', 'dogs'],
#  ['./train/dogs/dog.2307.jpg', 'dogs'],
#  ['./train/dogs/dog.628.jpg', 'dogs'],
#  ['./train/dogs/dog.3019.jpg', 'dogs'],
#  ['./train/dogs/dog.4776.jpg', 'dogs'],
#  ['./train/dogs/dog.23.jpg', 'dogs'],
#  ['./train/dogs/dog.9252.jpg', 'dogs'],
#  ['./train/dogs/dog.6161.jpg', 'dogs'],
#  ['./train/dogs/dog.8158.jpg', 'dogs'],
#  ['./train/dogs/dog.37.jpg', 'dogs'],
#  ['./train/dogs/dog.9246.jpg', 'dogs'],
#  ['./train/dogs/dog.6175.jpg', 'dogs'],
#  ['./train/dogs/dog.10355.jpg', 'dogs'],
#  ['./train/dogs/dog.2313.jpg', 'dogs'],
#  ['./train/dogs/dog.4762.jpg', 'dogs'],
#  ['./train/dogs/dog.4004.jpg', 'dogs'],
#  ['./train/dogs/dog.2475.jpg', 'dogs'],
#  ['./train/dogs/dog.10433.jpg', 'dogs'],
#  ['./train/dogs/dog.9520.jpg', 'dogs'],
#  ['./train/dogs/dog.6613.jpg', 'dogs'],
#  ['./train/dogs/dog.12224.jpg', 'dogs'],
#  ['./train/dogs/dog.11705.jpg', 'dogs'],
#  ['./train/dogs/dog.172.jpg', 'dogs'],
#  ['./train/dogs/dog.3743.jpg', 'dogs'],
#  ['./train/dogs/dog.5332.jpg', 'dogs'],
#  ['./train/dogs/dog.9508.jpg', 'dogs'],
#  ['./train/dogs/dog.1154.jpg', 'dogs'],
#  ['./train/dogs/dog.7525.jpg', 'dogs'],
#  ['./train/dogs/dog.8616.jpg', 'dogs'],
#  ['./train/dogs/dog.7243.jpg', 'dogs'],
#  ['./train/dogs/dog.8170.jpg', 'dogs'],
#  ['./train/dogs/dog.1632.jpg', 'dogs'],
#  ['./train/dogs/dog.5454.jpg', 'dogs'],
#  ['./train/dogs/dog.4992.jpg', 'dogs'],
#  ['./train/dogs/dog.614.jpg', 'dogs'],
#  ['./train/dogs/dog.3025.jpg', 'dogs'],
#  ['./train/dogs/dog.11063.jpg', 'dogs'],
#  ['./train/dogs/dog.5440.jpg', 'dogs'],
#  ['./train/dogs/dog.10369.jpg', 'dogs'],
#  ['./train/dogs/dog.4986.jpg', 'dogs'],
#  ['./train/dogs/dog.3031.jpg', 'dogs'],
#  ['./train/dogs/dog.600.jpg', 'dogs'],
#  ['./train/dogs/dog.11077.jpg', 'dogs'],
#  ['./train/dogs/dog.7257.jpg', 'dogs'],
#  ['./train/dogs/dog.8164.jpg', 'dogs'],
#  ['./train/dogs/dog.1626.jpg', 'dogs'],
#  ['./train/dogs/dog.6149.jpg', 'dogs'],
#  ['./train/dogs/dog.1140.jpg', 'dogs'],
#  ['./train/dogs/dog.12218.jpg', 'dogs'],
#  ['./train/dogs/dog.7531.jpg', 'dogs'],
#  ['./train/dogs/dog.8602.jpg', 'dogs'],
#  ['./train/dogs/dog.4038.jpg', 'dogs'],
#  ['./train/dogs/dog.11711.jpg', 'dogs'],
#  ['./train/dogs/dog.3757.jpg', 'dogs'],
#  ['./train/dogs/dog.166.jpg', 'dogs'],
#  ['./train/dogs/dog.2449.jpg', 'dogs'],
#  ['./train/dogs/dog.5326.jpg', 'dogs'],
#  ['./train/dogs/dog.10180.jpg', 'dogs'],
#  ['./train/dogs/dog.5871.jpg', 'dogs'],
#  ['./train/dogs/dog.9093.jpg', 'dogs'],
#  ['./train/dogs/dog.7900.jpg', 'dogs'],
#  ['./train/dogs/dog.2878.jpg', 'dogs'],
#  ['./train/dogs/dog.7914.jpg', 'dogs'],
#  ['./train/dogs/dog.9939.jpg', 'dogs'],
#  ['./train/dogs/dog.8399.jpg', 'dogs'],
#  ['./train/dogs/dog.9087.jpg', 'dogs'],
#  ['./train/dogs/dog.10194.jpg', 'dogs'],
#  ['./train/dogs/dog.5865.jpg', 'dogs'],
#  ['./train/dogs/dog.7082.jpg', 'dogs'],
#  ['./train/dogs/dog.5695.jpg', 'dogs'],
#  ['./train/dogs/dog.10802.jpg', 'dogs'],
#  ['./train/dogs/dog.3582.jpg', 'dogs'],
#  ['./train/dogs/dog.2844.jpg', 'dogs'],
#  ['./train/dogs/dog.1395.jpg', 'dogs'],
#  ['./train/dogs/dog.9911.jpg', 'dogs'],
#  ['./train/dogs/dog.1381.jpg', 'dogs'],
#  ['./train/dogs/dog.7928.jpg', 'dogs'],
#  ['./train/dogs/dog.9905.jpg', 'dogs'],
#  ['./train/dogs/dog.10816.jpg', 'dogs'],
#  ['./train/dogs/dog.3596.jpg', 'dogs'],
#  ['./train/dogs/dog.2850.jpg', 'dogs'],
#  ['./train/dogs/dog.2688.jpg', 'dogs'],
#  ['./train/dogs/dog.5681.jpg', 'dogs'],
#  ['./train/dogs/dog.5859.jpg', 'dogs'],
#  ['./train/dogs/dog.7096.jpg', 'dogs'],
#  ['./train/dogs/dog.6388.jpg', 'dogs'],
#  ['./train/dogs/dog.6363.jpg', 'dogs'],
#  ['./train/dogs/dog.9050.jpg', 'dogs'],
#  ['./train/dogs/dog.4574.jpg', 'dogs'],
#  ['./train/dogs/dog.2105.jpg', 'dogs'],
#  ['./train/dogs/dog.10143.jpg', 'dogs'],
#  ['./train/dogs/dog.10625.jpg', 'dogs'],
#  ['./train/dogs/dog.2663.jpg', 'dogs'],
#  ['./train/dogs/dog.4212.jpg', 'dogs'],
#  ['./train/dogs/dog.12032.jpg', 'dogs'],
#  ['./train/dogs/dog.8428.jpg', 'dogs'],
#  ['./train/dogs/dog.6405.jpg', 'dogs'],
#  ['./train/dogs/dog.9736.jpg', 'dogs'],
#  ['./train/dogs/dog.12026.jpg', 'dogs'],
#  ['./train/dogs/dog.6411.jpg', 'dogs'],
#  ['./train/dogs/dog.9722.jpg', 'dogs'],
#  ['./train/dogs/dog.5118.jpg', 'dogs'],
#  ['./train/dogs/dog.10631.jpg', 'dogs'],
#  ['./train/dogs/dog.2677.jpg', 'dogs'],
#  ['./train/dogs/dog.3569.jpg', 'dogs'],
#  ['./train/dogs/dog.358.jpg', 'dogs'],
#  ['./train/dogs/dog.4206.jpg', 'dogs'],
#  ['./train/dogs/dog.4560.jpg', 'dogs'],
#  ['./train/dogs/dog.11249.jpg', 'dogs'],
#  ['./train/dogs/dog.2111.jpg', 'dogs'],
#  ['./train/dogs/dog.10157.jpg', 'dogs'],
#  ['./train/dogs/dog.6377.jpg', 'dogs'],
#  ['./train/dogs/dog.9044.jpg', 'dogs'],
#  ['./train/dogs/dog.1418.jpg', 'dogs'],
#  ['./train/dogs/dog.7069.jpg', 'dogs'],
#  ['./train/dogs/dog.11261.jpg', 'dogs'],
#  ['./train/dogs/dog.4548.jpg', 'dogs'],
#  ['./train/dogs/dog.416.jpg', 'dogs'],
#  ['./train/dogs/dog.3227.jpg', 'dogs'],
#  ['./train/dogs/dog.2139.jpg', 'dogs'],
#  ['./train/dogs/dog.5656.jpg', 'dogs'],
#  ['./train/dogs/dog.1430.jpg', 'dogs'],
#  ['./train/dogs/dog.8372.jpg', 'dogs'],
#  ['./train/dogs/dog.7041.jpg', 'dogs'],
#  ['./train/dogs/dog.8414.jpg', 'dogs'],
#  ['./train/dogs/dog.7727.jpg', 'dogs'],
#  ['./train/dogs/dog.1356.jpg', 'dogs'],
#  ['./train/dogs/dog.6439.jpg', 'dogs'],
#  ['./train/dogs/dog.10619.jpg', 'dogs'],
#  ['./train/dogs/dog.5130.jpg', 'dogs'],
#  ['./train/dogs/dog.370.jpg', 'dogs'],
#  ['./train/dogs/dog.3541.jpg', 'dogs'],
#  ['./train/dogs/dog.11507.jpg', 'dogs'],
#  ['./train/dogs/dog.2887.jpg', 'dogs'],
#  ['./train/dogs/dog.5124.jpg', 'dogs'],
#  ['./train/dogs/dog.3555.jpg', 'dogs'],
#  ['./train/dogs/dog.364.jpg', 'dogs'],
#  ['./train/dogs/dog.11513.jpg', 'dogs'],
#  ['./train/dogs/dog.2893.jpg', 'dogs'],
#  ['./train/dogs/dog.8400.jpg', 'dogs'],
#  ['./train/dogs/dog.7733.jpg', 'dogs'],
#  ['./train/dogs/dog.1342.jpg', 'dogs'],
#  ['./train/dogs/dog.9078.jpg', 'dogs'],
#  ['./train/dogs/dog.1424.jpg', 'dogs'],
#  ['./train/dogs/dog.8366.jpg', 'dogs'],
#  ['./train/dogs/dog.7055.jpg', 'dogs'],
#  ['./train/dogs/dog.11275.jpg', 'dogs'],
#  ['./train/dogs/dog.3233.jpg', 'dogs'],
#  ['./train/dogs/dog.402.jpg', 'dogs'],
#  ['./train/dogs/dog.5642.jpg', 'dogs'],
#  ['./train/dogs/dog.5905.jpg', 'dogs'],
#  ['./train/dogs/dog.9859.jpg', 'dogs'],
#  ['./train/dogs/dog.12185.jpg', 'dogs'],
#  ['./train/dogs/dog.9681.jpg', 'dogs'],
#  ['./train/dogs/dog.7874.jpg', 'dogs'],
#  ['./train/dogs/dog.10792.jpg', 'dogs'],
#  ['./train/dogs/dog.10786.jpg', 'dogs'],
#  ['./train/dogs/dog.2918.jpg', 'dogs'],
#  ['./train/dogs/dog.11498.jpg', 'dogs'],
#  ['./train/dogs/dog.12191.jpg', 'dogs'],
#  ['./train/dogs/dog.9695.jpg', 'dogs'],
#  ['./train/dogs/dog.7860.jpg', 'dogs'],
#  ['./train/dogs/dog.589.jpg', 'dogs'],
#  ['./train/dogs/dog.5911.jpg', 'dogs'],
#  ['./train/dogs/dog.1587.jpg', 'dogs'],
#  ['./train/dogs/dog.5939.jpg', 'dogs'],
#  ['./train/dogs/dog.3390.jpg', 'dogs'],
#  ['./train/dogs/dog.5087.jpg', 'dogs'],
#  ['./train/dogs/dog.4399.jpg', 'dogs'],
#  ['./train/dogs/dog.2930.jpg', 'dogs'],
#  ['./train/dogs/dog.10976.jpg', 'dogs'],
#  ['./train/dogs/dog.9865.jpg', 'dogs'],
#  ['./train/dogs/dog.7690.jpg', 'dogs'],
#  ['./train/dogs/dog.7848.jpg', 'dogs'],
#  ['./train/dogs/dog.9871.jpg', 'dogs'],
#  ['./train/dogs/dog.7684.jpg', 'dogs'],
#  ['./train/dogs/dog.5093.jpg', 'dogs'],
#  ['./train/dogs/dog.2924.jpg', 'dogs'],
#  ['./train/dogs/dog.10962.jpg', 'dogs'],
#  ['./train/dogs/dog.3384.jpg', 'dogs'],
#  ['./train/dogs/dog.1593.jpg', 'dogs'],
#  ['./train/dogs/dog.7109.jpg', 'dogs'],
#  ['./train/dogs/dog.1578.jpg', 'dogs'],
#  ['./train/dogs/dog.6217.jpg', 'dogs'],
#  ['./train/dogs/dog.9124.jpg', 'dogs'],
#  ['./train/dogs/dog.10037.jpg', 'dogs'],
#  ['./train/dogs/dog.2071.jpg', 'dogs'],
#  ['./train/dogs/dog.4400.jpg', 'dogs'],
#  ['./train/dogs/dog.11329.jpg', 'dogs'],
#  ['./train/dogs/dog.4366.jpg', 'dogs'],
#  ['./train/dogs/dog.3409.jpg', 'dogs'],
#  ['./train/dogs/dog.238.jpg', 'dogs'],
#  ['./train/dogs/dog.10989.jpg', 'dogs'],
#  ['./train/dogs/dog.2717.jpg', 'dogs'],
#  ['./train/dogs/dog.5078.jpg', 'dogs'],
#  ['./train/dogs/dog.10751.jpg', 'dogs'],
#  ['./train/dogs/dog.6571.jpg', 'dogs'],
#  ['./train/dogs/dog.9642.jpg', 'dogs'],
#  ['./train/dogs/dog.12146.jpg', 'dogs'],
#  ['./train/dogs/dog.6565.jpg', 'dogs'],
#  ['./train/dogs/dog.9656.jpg', 'dogs'],
#  ['./train/dogs/dog.12152.jpg', 'dogs'],
#  ['./train/dogs/dog.8548.jpg', 'dogs'],
#  ['./train/dogs/dog.4372.jpg', 'dogs'],
#  ['./train/dogs/dog.2703.jpg', 'dogs'],
#  ['./train/dogs/dog.10745.jpg', 'dogs'],
#  ['./train/dogs/dog.10023.jpg', 'dogs'],
#  ['./train/dogs/dog.2065.jpg', 'dogs'],
#  ['./train/dogs/dog.4414.jpg', 'dogs'],
#  ['./train/dogs/dog.6203.jpg', 'dogs'],
#  ['./train/dogs/dog.9130.jpg', 'dogs'],
#  ['./train/dogs/dog.5722.jpg', 'dogs'],
#  ['./train/dogs/dog.3353.jpg', 'dogs'],
#  ['./train/dogs/dog.562.jpg', 'dogs'],
#  ['./train/dogs/dog.11315.jpg', 'dogs'],
#  ['./train/dogs/dog.8206.jpg', 'dogs'],
#  ['./train/dogs/dog.7135.jpg', 'dogs'],
#  ['./train/dogs/dog.1544.jpg', 'dogs'],
#  ['./train/dogs/dog.9118.jpg', 'dogs'],
#  ['./train/dogs/dog.1222.jpg', 'dogs'],
#  ['./train/dogs/dog.8560.jpg', 'dogs'],
#  ['./train/dogs/dog.7653.jpg', 'dogs'],
#  ['./train/dogs/dog.11473.jpg', 'dogs'],
#  ['./train/dogs/dog.3435.jpg', 'dogs'],
#  ['./train/dogs/dog.204.jpg', 'dogs'],
#  ['./train/dogs/dog.5044.jpg', 'dogs'],
#  ['./train/dogs/dog.11467.jpg', 'dogs'],
#  ['./train/dogs/dog.210.jpg', 'dogs'],
#  ['./train/dogs/dog.3421.jpg', 'dogs'],
#  ['./train/dogs/dog.10779.jpg', 'dogs'],
#  ['./train/dogs/dog.5050.jpg', 'dogs'],
#  ['./train/dogs/dog.6559.jpg', 'dogs'],
#  ['./train/dogs/dog.1236.jpg', 'dogs'],
#  ['./train/dogs/dog.8574.jpg', 'dogs'],
#  ['./train/dogs/dog.7647.jpg', 'dogs'],
#  ['./train/dogs/dog.8212.jpg', 'dogs'],
#  ['./train/dogs/dog.7121.jpg', 'dogs'],
#  ['./train/dogs/dog.1550.jpg', 'dogs'],
#  ['./train/dogs/dog.5736.jpg', 'dogs'],
#  ['./train/dogs/dog.2059.jpg', 'dogs'],
#  ['./train/dogs/dog.576.jpg', 'dogs'],
#  ['./train/dogs/dog.3347.jpg', 'dogs'],
#  ['./train/dogs/dog.11301.jpg', 'dogs'],
#  ['./train/dogs/dog.4428.jpg', 'dogs'],
#  ['./train/dogs/dog.10590.jpg', 'dogs'],
#  ['./train/dogs/dog.3810.jpg', 'dogs'],
#  ['./train/dogs/dog.11856.jpg', 'dogs'],
#  ['./train/dogs/dog.8945.jpg', 'dogs'],
#  ['./train/dogs/dog.9483.jpg', 'dogs'],
#  ['./train/dogs/dog.12387.jpg', 'dogs'],
#  ['./train/dogs/dog.6968.jpg', 'dogs'],
#  ['./train/dogs/dog.1961.jpg', 'dogs'],
#  ['./train/dogs/dog.4819.jpg', 'dogs'],
#  ['./train/dogs/dog.947.jpg', 'dogs'],
#  ['./train/dogs/dog.953.jpg', 'dogs'],
#  ['./train/dogs/dog.1975.jpg', 'dogs'],
#  ['./train/dogs/dog.8951.jpg', 'dogs'],
#  ['./train/dogs/dog.9497.jpg', 'dogs'],
#  ['./train/dogs/dog.8789.jpg', 'dogs'],
#  ['./train/dogs/dog.12393.jpg', 'dogs'],
#  ['./train/dogs/dog.10584.jpg', 'dogs'],
#  ['./train/dogs/dog.3804.jpg', 'dogs'],
#  ['./train/dogs/dog.11842.jpg', 'dogs'],
#  ['./train/dogs/dog.8979.jpg', 'dogs'],
#  ['./train/dogs/dog.7492.jpg', 'dogs'],
#  ['./train/dogs/dog.6954.jpg', 'dogs'],
#  ['./train/dogs/dog.5285.jpg', 'dogs'],
#  ['./train/dogs/dog.4825.jpg', 'dogs'],
#  ['./train/dogs/dog.3192.jpg', 'dogs'],
#  ['./train/dogs/dog.1785.jpg', 'dogs'],
#  ['./train/dogs/dog.1949.jpg', 'dogs'],
#  ['./train/dogs/dog.1791.jpg', 'dogs'],
#  ['./train/dogs/dog.2298.jpg', 'dogs'],
#  ['./train/dogs/dog.4831.jpg', 'dogs'],
#  ['./train/dogs/dog.3186.jpg', 'dogs'],
#  ['./train/dogs/dog.3838.jpg', 'dogs'],
#  ['./train/dogs/dog.5291.jpg', 'dogs'],
#  ['./train/dogs/dog.6798.jpg', 'dogs'],
#  ['./train/dogs/dog.7486.jpg', 'dogs'],
#  ['./train/dogs/dog.6940.jpg', 'dogs'],
#  ['./train/dogs/dog.12344.jpg', 'dogs'],
#  ['./train/dogs/dog.8986.jpg', 'dogs'],
#  ['./train/dogs/dog.9440.jpg', 'dogs'],
#  ['./train/dogs/dog.6773.jpg', 'dogs'],
#  ['./train/dogs/dog.10553.jpg', 'dogs'],
#  ['./train/dogs/dog.11895.jpg', 'dogs'],
#  ['./train/dogs/dog.2515.jpg', 'dogs'],
#  ['./train/dogs/dog.4164.jpg', 'dogs'],
#  ['./train/dogs/dog.4602.jpg', 'dogs'],
#  ['./train/dogs/dog.2273.jpg', 'dogs'],
#  ['./train/dogs/dog.10235.jpg', 'dogs'],
#  ['./train/dogs/dog.984.jpg', 'dogs'],
#  ['./train/dogs/dog.9326.jpg', 'dogs'],
#  ['./train/dogs/dog.6015.jpg', 'dogs'],
#  ['./train/dogs/dog.8038.jpg', 'dogs'],
#  ['./train/dogs/dog.12422.jpg', 'dogs'],
#  ['./train/dogs/dog.9332.jpg', 'dogs'],
#  ['./train/dogs/dog.6001.jpg', 'dogs'],
#  ['./train/dogs/dog.12436.jpg', 'dogs'],
#  ['./train/dogs/dog.4616.jpg', 'dogs'],
#  ['./train/dogs/dog.748.jpg', 'dogs'],
#  ['./train/dogs/dog.3179.jpg', 'dogs'],
#  ['./train/dogs/dog.2267.jpg', 'dogs'],
#  ['./train/dogs/dog.10221.jpg', 'dogs'],
#  ['./train/dogs/dog.5508.jpg', 'dogs'],
#  ['./train/dogs/dog.990.jpg', 'dogs'],
#  ['./train/dogs/dog.10547.jpg', 'dogs'],
#  ['./train/dogs/dog.11881.jpg', 'dogs'],
#  ['./train/dogs/dog.2501.jpg', 'dogs'],
#  ['./train/dogs/dog.11659.jpg', 'dogs'],
#  ['./train/dogs/dog.4170.jpg', 'dogs'],
#  ['./train/dogs/dog.7479.jpg', 'dogs'],
#  ['./train/dogs/dog.12350.jpg', 'dogs'],
#  ['./train/dogs/dog.8992.jpg', 'dogs'],
#  ['./train/dogs/dog.1008.jpg', 'dogs'],
#  ['./train/dogs/dog.9454.jpg', 'dogs'],
#  ['./train/dogs/dog.6767.jpg', 'dogs'],
#  ['./train/dogs/dog.5246.jpg', 'dogs'],
#  ['./train/dogs/dog.2529.jpg', 'dogs'],
#  ['./train/dogs/dog.3637.jpg', 'dogs'],
#  ['./train/dogs/dog.4158.jpg', 'dogs'],
#  ['./train/dogs/dog.11671.jpg', 'dogs'],
#  ['./train/dogs/dog.12378.jpg', 'dogs'],
#  ['./train/dogs/dog.7451.jpg', 'dogs'],
#  ['./train/dogs/dog.8762.jpg', 'dogs'],
#  ['./train/dogs/dog.6997.jpg', 'dogs'],
#  ['./train/dogs/dog.1020.jpg', 'dogs'],
#  ['./train/dogs/dog.6029.jpg', 'dogs'],
#  ['./train/dogs/dog.1746.jpg', 'dogs'],
#  ['./train/dogs/dog.7337.jpg', 'dogs'],
#  ['./train/dogs/dog.8004.jpg', 'dogs'],
#  ['./train/dogs/dog.11117.jpg', 'dogs'],
#  ['./train/dogs/dog.3151.jpg', 'dogs'],
#  ['./train/dogs/dog.760.jpg', 'dogs'],
#  ['./train/dogs/dog.5520.jpg', 'dogs'],
#  ['./train/dogs/dog.10209.jpg', 'dogs'],
#  ['./train/dogs/dog.11103.jpg', 'dogs'],
#  ['./train/dogs/dog.774.jpg', 'dogs'],
#  ['./train/dogs/dog.3145.jpg', 'dogs'],
#  ['./train/dogs/dog.5534.jpg', 'dogs'],
#  ['./train/dogs/dog.1752.jpg', 'dogs'],
#  ['./train/dogs/dog.7323.jpg', 'dogs'],
#  ['./train/dogs/dog.8010.jpg', 'dogs'],
#  ['./train/dogs/dog.7445.jpg', 'dogs'],
#  ['./train/dogs/dog.8776.jpg', 'dogs'],
#  ['./train/dogs/dog.6983.jpg', 'dogs'],
#  ['./train/dogs/dog.1034.jpg', 'dogs'],
#  ['./train/dogs/dog.9468.jpg', 'dogs'],
#  ['./train/dogs/dog.5252.jpg', 'dogs'],
#  ['./train/dogs/dog.3623.jpg', 'dogs'],
#  ['./train/dogs/dog.11665.jpg', 'dogs'],
#  ['./train/dogs/dog.5522.jpg', 'dogs'],
#  ['./train/dogs/dog.762.jpg', 'dogs'],
#  ['./train/dogs/dog.3153.jpg', 'dogs'],
#  ['./train/dogs/dog.11115.jpg', 'dogs'],
#  ['./train/dogs/dog.7335.jpg', 'dogs'],
#  ['./train/dogs/dog.8006.jpg', 'dogs'],
#  ['./train/dogs/dog.1744.jpg', 'dogs'],
#  ['./train/dogs/dog.9318.jpg', 'dogs'],
#  ['./train/dogs/dog.1022.jpg', 'dogs'],
#  ['./train/dogs/dog.6995.jpg', 'dogs'],
#  ['./train/dogs/dog.7453.jpg', 'dogs'],
#  ['./train/dogs/dog.8760.jpg', 'dogs'],
#  ['./train/dogs/dog.11673.jpg', 'dogs'],
#  ['./train/dogs/dog.3635.jpg', 'dogs'],
#  ['./train/dogs/dog.5244.jpg', 'dogs'],
#  ['./train/dogs/dog.11667.jpg', 'dogs'],
#  ['./train/dogs/dog.3621.jpg', 'dogs'],
#  ['./train/dogs/dog.10579.jpg', 'dogs'],
#  ['./train/dogs/dog.5250.jpg', 'dogs'],
#  ['./train/dogs/dog.6759.jpg', 'dogs'],
#  ['./train/dogs/dog.1036.jpg', 'dogs'],
#  ['./train/dogs/dog.6981.jpg', 'dogs'],
#  ['./train/dogs/dog.7447.jpg', 'dogs'],
#  ['./train/dogs/dog.8774.jpg', 'dogs'],
#  ['./train/dogs/dog.7321.jpg', 'dogs'],
#  ['./train/dogs/dog.12408.jpg', 'dogs'],
#  ['./train/dogs/dog.1988.jpg', 'dogs'],
#  ['./train/dogs/dog.8012.jpg', 'dogs'],
#  ['./train/dogs/dog.1750.jpg', 'dogs'],
#  ['./train/dogs/dog.5536.jpg', 'dogs'],
#  ['./train/dogs/dog.2259.jpg', 'dogs'],
#  ['./train/dogs/dog.3147.jpg', 'dogs'],
#  ['./train/dogs/dog.776.jpg', 'dogs'],
#  ['./train/dogs/dog.11101.jpg', 'dogs'],
#  ['./train/dogs/dog.4628.jpg', 'dogs'],
#  ['./train/dogs/dog.12420.jpg', 'dogs'],
#  ['./train/dogs/dog.7309.jpg', 'dogs'],
#  ['./train/dogs/dog.1778.jpg', 'dogs'],
#  ['./train/dogs/dog.9324.jpg', 'dogs'],
#  ['./train/dogs/dog.6017.jpg', 'dogs'],
#  ['./train/dogs/dog.10237.jpg', 'dogs'],
#  ['./train/dogs/dog.986.jpg', 'dogs'],
#  ['./train/dogs/dog.2271.jpg', 'dogs'],
#  ['./train/dogs/dog.4600.jpg', 'dogs'],
#  ['./train/dogs/dog.11129.jpg', 'dogs'],
#  ['./train/dogs/dog.4166.jpg', 'dogs'],
#  ['./train/dogs/dog.3609.jpg', 'dogs'],
#  ['./train/dogs/dog.11897.jpg', 'dogs'],
#  ['./train/dogs/dog.2517.jpg', 'dogs'],
#  ['./train/dogs/dog.5278.jpg', 'dogs'],
#  ['./train/dogs/dog.10551.jpg', 'dogs'],
#  ['./train/dogs/dog.9442.jpg', 'dogs'],
#  ['./train/dogs/dog.6771.jpg', 'dogs'],
#  ['./train/dogs/dog.8984.jpg', 'dogs'],
#  ['./train/dogs/dog.12346.jpg', 'dogs'],
#  ['./train/dogs/dog.9456.jpg', 'dogs'],
#  ['./train/dogs/dog.6765.jpg', 'dogs'],
#  ['./train/dogs/dog.8990.jpg', 'dogs'],
#  ['./train/dogs/dog.8748.jpg', 'dogs'],
#  ['./train/dogs/dog.12352.jpg', 'dogs'],
#  ['./train/dogs/dog.4172.jpg', 'dogs'],
#  ['./train/dogs/dog.11883.jpg', 'dogs'],
#  ['./train/dogs/dog.2503.jpg', 'dogs'],
#  ['./train/dogs/dog.10545.jpg', 'dogs'],
#  ['./train/dogs/dog.10223.jpg', 'dogs'],
#  ['./train/dogs/dog.992.jpg', 'dogs'],
#  ['./train/dogs/dog.2265.jpg', 'dogs'],
#  ['./train/dogs/dog.4614.jpg', 'dogs'],
#  ['./train/dogs/dog.12434.jpg', 'dogs'],
#  ['./train/dogs/dog.9330.jpg', 'dogs'],
#  ['./train/dogs/dog.6003.jpg', 'dogs'],
#  ['./train/dogs/dog.1787.jpg', 'dogs'],
#  ['./train/dogs/dog.3190.jpg', 'dogs'],
#  ['./train/dogs/dog.979.jpg', 'dogs'],
#  ['./train/dogs/dog.4827.jpg', 'dogs'],
#  ['./train/dogs/dog.11868.jpg', 'dogs'],
#  ['./train/dogs/dog.5287.jpg', 'dogs'],
#  ['./train/dogs/dog.4199.jpg', 'dogs'],
#  ['./train/dogs/dog.6956.jpg', 'dogs'],
#  ['./train/dogs/dog.7490.jpg', 'dogs'],
#  ['./train/dogs/dog.6942.jpg', 'dogs'],
#  ['./train/dogs/dog.7484.jpg', 'dogs'],
#  ['./train/dogs/dog.5293.jpg', 'dogs'],
#  ['./train/dogs/dog.3184.jpg', 'dogs'],
#  ['./train/dogs/dog.4833.jpg', 'dogs'],
#  ['./train/dogs/dog.1793.jpg', 'dogs'],
#  ['./train/dogs/dog.945.jpg', 'dogs'],
#  ['./train/dogs/dog.1963.jpg', 'dogs'],
#  ['./train/dogs/dog.12385.jpg', 'dogs'],
#  ['./train/dogs/dog.9481.jpg', 'dogs'],
#  ['./train/dogs/dog.8947.jpg', 'dogs'],
#  ['./train/dogs/dog.11854.jpg', 'dogs'],
#  ['./train/dogs/dog.10592.jpg', 'dogs'],
#  ['./train/dogs/dog.3812.jpg', 'dogs'],
#  ['./train/dogs/dog.11840.jpg', 'dogs'],
#  ['./train/dogs/dog.10586.jpg', 'dogs'],
#  ['./train/dogs/dog.3806.jpg', 'dogs'],
#  ['./train/dogs/dog.11698.jpg', 'dogs'],
#  ['./train/dogs/dog.12391.jpg', 'dogs'],
#  ['./train/dogs/dog.9495.jpg', 'dogs'],
#  ['./train/dogs/dog.8953.jpg', 'dogs'],
#  ['./train/dogs/dog.1977.jpg', 'dogs'],
#  ['./train/dogs/dog.789.jpg', 'dogs'],
#  ['./train/dogs/dog.951.jpg', 'dogs'],
#  ['./train/dogs/dog.5046.jpg', 'dogs'],
#  ['./train/dogs/dog.2729.jpg', 'dogs'],
#  ['./train/dogs/dog.206.jpg', 'dogs'],
#  ['./train/dogs/dog.3437.jpg', 'dogs'],
#  ['./train/dogs/dog.4358.jpg', 'dogs'],
#  ['./train/dogs/dog.11471.jpg', 'dogs'],
#  ['./train/dogs/dog.8562.jpg', 'dogs'],
#  ['./train/dogs/dog.12178.jpg', 'dogs'],
#  ['./train/dogs/dog.7651.jpg', 'dogs'],
#  ['./train/dogs/dog.1220.jpg', 'dogs'],
#  ['./train/dogs/dog.7889.jpg', 'dogs'],
#  ['./train/dogs/dog.6229.jpg', 'dogs'],
#  ['./train/dogs/dog.1546.jpg', 'dogs'],
#  ['./train/dogs/dog.8204.jpg', 'dogs'],
#  ['./train/dogs/dog.7137.jpg', 'dogs'],
#  ['./train/dogs/dog.11317.jpg', 'dogs'],
#  ['./train/dogs/dog.560.jpg', 'dogs'],
#  ['./train/dogs/dog.3351.jpg', 'dogs'],
#  ['./train/dogs/dog.5720.jpg', 'dogs'],
#  ['./train/dogs/dog.10009.jpg', 'dogs'],
#  ['./train/dogs/dog.11303.jpg', 'dogs'],
#  ['./train/dogs/dog.3345.jpg', 'dogs'],
#  ['./train/dogs/dog.574.jpg', 'dogs'],
#  ['./train/dogs/dog.5734.jpg', 'dogs'],
#  ['./train/dogs/dog.1552.jpg', 'dogs'],
#  ['./train/dogs/dog.8210.jpg', 'dogs'],
#  ['./train/dogs/dog.7123.jpg', 'dogs'],
#  ['./train/dogs/dog.8576.jpg', 'dogs'],
#  ['./train/dogs/dog.7645.jpg', 'dogs'],
#  ['./train/dogs/dog.1234.jpg', 'dogs'],
#  ['./train/dogs/dog.9668.jpg', 'dogs'],
#  ['./train/dogs/dog.5052.jpg', 'dogs'],
#  ['./train/dogs/dog.3423.jpg', 'dogs'],
#  ['./train/dogs/dog.212.jpg', 'dogs'],
#  ['./train/dogs/dog.11465.jpg', 'dogs'],
#  ['./train/dogs/dog.12144.jpg', 'dogs'],
#  ['./train/dogs/dog.9898.jpg', 'dogs'],
#  ['./train/dogs/dog.6573.jpg', 'dogs'],
#  ['./train/dogs/dog.9640.jpg', 'dogs'],
#  ['./train/dogs/dog.10753.jpg', 'dogs'],
#  ['./train/dogs/dog.2715.jpg', 'dogs'],
#  ['./train/dogs/dog.4364.jpg', 'dogs'],
#  ['./train/dogs/dog.4402.jpg', 'dogs'],
#  ['./train/dogs/dog.2073.jpg', 'dogs'],
#  ['./train/dogs/dog.10035.jpg', 'dogs'],
#  ['./train/dogs/dog.6215.jpg', 'dogs'],
#  ['./train/dogs/dog.9126.jpg', 'dogs'],
#  ['./train/dogs/dog.8238.jpg', 'dogs'],
#  ['./train/dogs/dog.6201.jpg', 'dogs'],
#  ['./train/dogs/dog.9132.jpg', 'dogs'],
#  ['./train/dogs/dog.4416.jpg', 'dogs'],
#  ['./train/dogs/dog.3379.jpg', 'dogs'],
#  ['./train/dogs/dog.548.jpg', 'dogs'],
#  ['./train/dogs/dog.2067.jpg', 'dogs'],
#  ['./train/dogs/dog.10021.jpg', 'dogs'],
#  ['./train/dogs/dog.5708.jpg', 'dogs'],
#  ['./train/dogs/dog.10747.jpg', 'dogs'],
#  ['./train/dogs/dog.2701.jpg', 'dogs'],
#  ['./train/dogs/dog.11459.jpg', 'dogs'],
#  ['./train/dogs/dog.4370.jpg', 'dogs'],
#  ['./train/dogs/dog.7679.jpg', 'dogs'],
#  ['./train/dogs/dog.12150.jpg', 'dogs'],
#  ['./train/dogs/dog.1208.jpg', 'dogs'],
#  ['./train/dogs/dog.6567.jpg', 'dogs'],
#  ['./train/dogs/dog.9654.jpg', 'dogs'],
#  ['./train/dogs/dog.7692.jpg', 'dogs'],
#  ['./train/dogs/dog.9867.jpg', 'dogs'],
#  ['./train/dogs/dog.10974.jpg', 'dogs'],
#  ['./train/dogs/dog.2932.jpg', 'dogs'],
#  ['./train/dogs/dog.5085.jpg', 'dogs'],
#  ['./train/dogs/dog.3392.jpg', 'dogs'],
#  ['./train/dogs/dog.1585.jpg', 'dogs'],
#  ['./train/dogs/dog.1591.jpg', 'dogs'],
#  ['./train/dogs/dog.2098.jpg', 'dogs'],
#  ['./train/dogs/dog.3386.jpg', 'dogs'],
#  ['./train/dogs/dog.10960.jpg', 'dogs'],
#  ['./train/dogs/dog.2926.jpg', 'dogs'],
#  ['./train/dogs/dog.5091.jpg', 'dogs'],
#  ['./train/dogs/dog.6598.jpg', 'dogs'],
#  ['./train/dogs/dog.7686.jpg', 'dogs'],
#  ['./train/dogs/dog.9873.jpg', 'dogs'],
#  ['./train/dogs/dog.10948.jpg', 'dogs'],
#  ['./train/dogs/dog.10790.jpg', 'dogs'],
#  ['./train/dogs/dog.7876.jpg', 'dogs'],
#  ['./train/dogs/dog.9683.jpg', 'dogs'],
#  ['./train/dogs/dog.12187.jpg', 'dogs'],
#  ['./train/dogs/dog.5907.jpg', 'dogs'],
#  ['./train/dogs/dog.5913.jpg', 'dogs'],
#  ['./train/dogs/dog.7862.jpg', 'dogs'],
#  ['./train/dogs/dog.9697.jpg', 'dogs'],
#  ['./train/dogs/dog.12193.jpg', 'dogs'],
#  ['./train/dogs/dog.8589.jpg', 'dogs'],
#  ['./train/dogs/dog.10784.jpg', 'dogs'],
#  ['./train/dogs/dog.11505.jpg', 'dogs'],
#  ['./train/dogs/dog.2885.jpg', 'dogs'],
#  ['./train/dogs/dog.3543.jpg', 'dogs'],
#  ['./train/dogs/dog.372.jpg', 'dogs'],
#  ['./train/dogs/dog.5132.jpg', 'dogs'],
#  ['./train/dogs/dog.9708.jpg', 'dogs'],
#  ['./train/dogs/dog.1354.jpg', 'dogs'],
#  ['./train/dogs/dog.8416.jpg', 'dogs'],
#  ['./train/dogs/dog.7725.jpg', 'dogs'],
#  ['./train/dogs/dog.8370.jpg', 'dogs'],
#  ['./train/dogs/dog.7043.jpg', 'dogs'],
#  ['./train/dogs/dog.1432.jpg', 'dogs'],
#  ['./train/dogs/dog.5654.jpg', 'dogs'],
#  ...]

# %%
img_path, class_name = data[0]

# %%
img_path
# Out:
# './train/dogs/dog.8011.jpg'

# %%
sub_dirs
# Out:
# ['./train/dogs', './train/cats']

# %%
img = Image.open('./train/dogs/dog.8011.jpg')

# %%
img_2 = Image.resize(img, (256,256))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [158], in <cell line: 1>()
# ----> 1 img_2 = Image.resize(img, (256,256))
#
# File ~/miniforge3/envs/pytorch/lib/python3.9/site-packages/PIL/Image.py:108, in __getattr__(name)
#      95         warnings.warn(
#      96             name
#      97             + " is "
#    (...)
#     105             stacklevel=2,
#     106         )
#     107         return enum[name]
# --> 108 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'PIL.Image' has no attribute 'resize'

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
train_set = datasets.FashionMNIST(root='data', train=True, download=True, transform=ToTensor(), target_transform=ToTensor())

# %%
type(train_set[0][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [225], in <cell line: 1>()
# ----> 1 type(train_set[0][1])
#
# File ~/miniforge3/envs/pytorch/lib/python3.9/site-packages/torchvision/datasets/mnist.py:148, in MNIST.__getitem__(self, index)
#     145     img = self.transform(img)
#     147 if self.target_transform is not None:
# --> 148     target = self.target_transform(target)
#     150 return img, target
#
# File ~/miniforge3/envs/pytorch/lib/python3.9/site-packages/torchvision/transforms/transforms.py:135, in ToTensor.__call__(self, pic)
#     127 def __call__(self, pic):
#     128     """
#     129     Args:
#     130         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     133         Tensor: Converted image.
#     134     """
# --> 135     return F.to_tensor(pic)
#
# File ~/miniforge3/envs/pytorch/lib/python3.9/site-packages/torchvision/transforms/functional.py:138, in to_tensor(pic)
#     136     _log_api_usage_once(to_tensor)
#     137 if not (F_pil._is_pil_image(pic) or _is_numpy(pic)):
# --> 138     raise TypeError(f"pic should be PIL Image or ndarray. Got {type(pic)}")
#     140 if _is_numpy(pic) and not _is_numpy_image(pic):
#     141     raise ValueError(f"pic should be 2/3 dimensional. Got {pic.ndim} dimensions.")
#
# TypeError: pic should be PIL Image or ndarray. Got <class 'int'>

# %%
import itertools as it

# %%
bills = [20, 20, 20, 10, 10, 10, 10, 10, 5, 5, 1, 1, 1, 1, 1]

# %%
len(list(it.combinations(bills, 3, )))
# Out:
# 455

# %%
len(list(it.combinations_with_replacement(bills, 3, )))
# Out:
# 680

# %%
len(list(it.permutations(bills, 3, )))
# Out:
# 2730

# %%
(list(it.product(bills, ['a'], ['b'])))
# Out:
# [(20, 'a', 'b'),
#  (20, 'a', 'b'),
#  (20, 'a', 'b'),
#  (10, 'a', 'b'),
#  (10, 'a', 'b'),
#  (10, 'a', 'b'),
#  (10, 'a', 'b'),
#  (10, 'a', 'b'),
#  (5, 'a', 'b'),
#  (5, 'a', 'b'),
#  (1, 'a', 'b'),
#  (1, 'a', 'b'),
#  (1, 'a', 'b'),
#  (1, 'a', 'b'),
#  (1, 'a', 'b')]
